# %%
import pandas as pd
from binance.client import Client

# %%
# insert API key / API Secret

api_key = ""
api_secret = ""

# %%
# connect to binance client
client = Client(api_key, api_secret)

# %%
# get candle from 1 Nov 2017 to 1 Nov 2021
BTCcandle = client.get_historical_klines("MANAUSDT", Client.KLINE_INTERVAL_1DAY, "1 Nov, 2017", "1 Nov, 2021")

# %%
# import into pandas dataframe
btc_df = pd.DataFrame(BTCcandle)
btc_df.columns = ['Open Time', 'Open', 'High', 'Low', 'Close', 'Volume', 'Close Time', 'Quote Asset Volume', 'No. Trade', 'TB Base Volume', 'TB Quote Volume', 'Ignore']

# %%
btc_df
# Out:
#           Open Time           Open           High            Low  \
# 0     1509494400000   304.89000000   305.90000000   286.34000000
# 1     1509580800000   287.30000000   293.00000000   274.73000000
# 2     1509667200000   283.12000000   307.00000000   282.00000000
# 3     1509753600000   304.09000000   304.99000000   292.11000000
# 4     1509840000000   298.10000000   302.14000000   293.13000000
# ...             ...            ...            ...            ...
# 1457  1635379200000  3921.99000000  4295.00000000  3890.17000000
# 1458  1635465600000  4286.01000000  4460.47000000  4265.97000000
# 1459  1635552000000  4418.89000000  4434.06000000  4232.20000000
# 1460  1635638400000  4322.68000000  4399.14000000  4164.35000000
# 1461  1635724800000  4287.48000000  4386.58000000  4146.30000000
#
#               Close           Volume     Close Time   Quote Asset Volume  \
# 0      287.01000000    9843.16660000  1509580799999     2948801.70630060
# ...

# %%
btc_df = btc_df[['Close Time', 'Close', 'Volume', 'Quote Asset Volume']]

btc_df['Close Time'] = pd.to_datetime(btc_df['Close Time']/1000, unit = 's')

# %%
btc_df['Close Time'] = btc_df['Close Time'].dt.date

# %%
btc_df['Close'] = btc_df['Close'].astype(float)
btc_df['Close'].round(2)

btc_df
# Out:
#      Close Time    Close               Volume   Quote Asset Volume
# 0    2020-08-06  0.05822    14196664.70000000      863503.86977700
# 1    2020-08-07  0.07484    51256029.90000000     3502922.89500800
# 2    2020-08-08  0.10281    85765140.70000000     7468578.76384300
# 3    2020-08-09  0.09972   137647520.20000000    15487532.97707600
# 4    2020-08-10  0.10139    71520828.90000000     7238474.46926600
# ..          ...      ...                  ...                  ...
# 448  2021-10-28  0.92460   115975865.00000000   103737230.37190000
# 449  2021-10-29  1.39530   775810210.45000000   974943911.78771200
# 450  2021-10-30  3.58800  1968305884.12000000  4910128108.39506100
# 451  2021-10-31  2.88500  1231089249.00000000  4030209759.94720000
# 452  2021-11-01  3.03390   630900562.00000000  1912024627.70570000
#
# [453 rows x 4 columns]

# %%
btc_df.to_csv("SAND_NOV2017_NOV2021.csv")
